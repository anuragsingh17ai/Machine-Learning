# %% [markdown]
#  Categorical variable type
#
#  *Nominal variable  -> text variable donot have any order between them example male ,female or red, green ,blue
#
# *ordinal variable -> here variable have ordering between them example satisfied ,neutral,dissatisfaction.

# %%
import pandas as pd
df
